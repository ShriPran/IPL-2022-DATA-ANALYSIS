# %% [markdown]
# # IPL 2022 DATA ANALYSIS

# %% [markdown]
# ![Screenshot%20%2812%29.png](attachment:Screenshot%20%2812%29.png)

# %% [markdown]
# ### AIM :
# ### Q1. Show the wins of each team in a pie chart?
# ### Q2. Find top 5 players who won player of the matches award?
# ### Q3. Does winning depends on winning the toss?

# %% [markdown]
# ## We will import kaggle dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv("C:/Users/prans/Downloads/archive (5)/IPL_Matches_2022.csv")
print(df)
# Out:
#          ID       City        Date  Season  MatchNumber  \
# 0   1304047     Mumbai  26-03-2022    2022            1
# 1   1304048     Mumbai  27-03-2022    2022            2
# 2   1304049     Mumbai  27-03-2022    2022            3
# 3   1304050     Mumbai  28-03-2022    2022            4
# 4   1304051       Pune  29-03-2022    2022            5
# ..      ...        ...         ...     ...          ...
# 69  1304116     Mumbai  22-05-2022    2022           70
# 70  1312198    Kolkata  25-05-2022    2022   Eliminator
# 71  1312200  Ahmedabad  29-05-2022    2022        Final
# 72  1312197    Kolkata  24-05-2022    2022  Qualifier 1
# 73  1312199  Ahmedabad  27-05-2022    2022  Qualifier 2
#
#                           Team1                  Team2  \
# 0           Chennai Super Kings  Kolkata Knight Riders
# 1                Mumbai Indians         Delhi Capitals
# 2   Royal Challengers Bangalore           Punjab Kings
# 3          Lucknow Super Giants         Gujarat Titans
# ...

# %% [markdown]
# ## To find  wins of each team

# %%
df['WinningTeam'].value_counts()
# Out:
# Gujarat Titans                 12
# Rajasthan Royals               10
# Royal Challengers Bangalore     9
# Lucknow Super Giants            9
# Delhi Capitals                  7
# Punjab Kings                    7
# Kolkata Knight Riders           6
# Sunrisers Hyderabad             6
# Chennai Super Kings             4
# Mumbai Indians                  4
# Name: WinningTeam, dtype: int64

# %%
y = np.array([12,10,9,9,7,7,6,6,4,4])
mylabels = ["Gujarat","Rajasthan","Bangalore","Lucknow","Delhi","Punjab","Kolkata","Hyderabad","Chennai","Mumbai"]
mycolors = ["#050650", "#c00e9b", "#ad0e0c", "#7bd7f3", "#4b109a", "#fc1b13", "#341b4d", "#f4914d", "#f0d44d", "#4510fc"]
plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# ## To Find top 5 players who won player of the matches award

# %%
df['Player_of_Match'].value_counts()
# Out:
# Kuldeep Yadav       4
# JC Buttler          3
# UT Yadav            2
# Q de Kock           2
# DA Miller           2
# Umran Malik         2
# KL Rahul            2
# RA Tripathi         2
# HH Pandya           2
# JJ Bumrah           2
# Shubman Gill        2
# YS Chahal           2
# PWH de Silva        2
# Avesh Khan          2
# KD Karthik          2
# V Kohli             1
# RK Singh            1
# K Rabada            1
# HV Patel            1
# DA Warner           1
# Harpreet Brar       1
# TH David            1
# YBK Jaiswal         1
# R Ashwin            1
# AD Russell          1
# SN Thakur           1
# TA Boult            1
# DP Conway           1
# WP Saha             1
# MR Marsh            1
# Mohsin Khan         1
# DR Sams             1
# JM Bairstow         1
# RD Gaikwad          1
# Rashid Khan         1
# SA Yadav            1
# Anuj Rawat          1
# OF Smith            1
# Mohammed Shami      1
# SV Samson           1
# E Lewis             1
# ...

# %%
x = np.array(["Kuldeep Yadav","Jos Buttler", "Umesh Yadav", "Quinton de Kock" , "David Miller"])
y = np.array([4,3,2,2,2])

plt.bar(x, y,width = 0.3)
plt.show()

# %% [markdown]
# ## After cleaning data and adding new column like Matches won based on toss decision
# ## We have our new data as shown below

# %%
df2 = pd.read_csv("C:\Pran's code\IPL_Matches_2022.csv")
print(df2)
# Out:
#          City  Unnamed: 1  Season  MatchNumber                        Team1  \
# 0      Mumbai         NaN    2022            1          Chennai Super Kings
# 1      Mumbai         NaN    2022            2               Mumbai Indians
# 2      Mumbai         NaN    2022            3  Royal Challengers Bangalore
# 3      Mumbai         NaN    2022            4         Lucknow Super Giants
# 4        Pune         NaN    2022            5             Rajasthan Royals
# ..        ...         ...     ...          ...                          ...
# 69     Mumbai         NaN    2022           70          Sunrisers Hyderabad
# 70    Kolkata         NaN    2022   Eliminator  Royal Challengers Bangalore
# 71  Ahmedabad         NaN    2022        Final             Rajasthan Royals
# 72    Kolkata         NaN    2022  Qualifier 1             Rajasthan Royals
# 73  Ahmedabad         NaN    2022  Qualifier 2  Royal Challengers Bangalore
#
# ...

# %%
df2['Matches won based on toss decision'].value_counts()
# Out:
# Lost the toss    38
# Tosswinner       36
# Name: Matches won based on toss decision, dtype: int64

# %%
y = np.array([38,36])
mylabels = ["Losing team","Toss winner"]
mycolors = ["#ff0000", "#3cd722"]
plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# ![Screenshot%20%2813%29.png](attachment:Screenshot%20%2813%29.png)

# %% [markdown]
# ## It shows that in ipl 2022 it doesn't matter who' s winning the toss as matches won by lossing toss team is higher than winning toss team

# %% [markdown]
# ## Conclusion:
# ## We can simplify the problem and can extract the crucial information from raw data using data science.

# %% [markdown]
# ## Source
# ## Kaggle dataset
# ## https://www.kaggle.com/datasets/vora1011/ipl-2022-match-dataset
